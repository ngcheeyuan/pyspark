349 West Rebekahport, AZ 44793</td><td>Abbott-Thompson</td><td>1</td></tr><tr><td>13</td><td>Nicole Olson</td><td>40.0</td><td>8283.32</td><td>1</td><td>5.1</td><td>13.0</td><td>2012-11-22T05:35:03.000+0000</td><td>11488 Weaver Cape Hernandezberg, WI 63417-8544</td><td>Smith, Kim and Marshall</td><td>1</td></tr><tr><td>14</td><td>Harold Griffin</td><td>41.0</td><td>6569.87</td><td>1</td><td>4.3</td><td>11.0</td><td>2015-03-28T02:13:44.000+0000</td><td>1774 Peter Row Apt. 712 New Autumn, MT 18782</td><td>Snyder, Lee and Morris</td><td>1</td></tr><tr><td>15</td><td>James Wright</td><td>38.0</td><td>10494.82</td><td>1</td><td>6.81</td><td>12.0</td><td>2015-07-22T08:38:40.000+0000</td><td>45408 David Path East Kimberlyshire, HI 54903-6698</td><td>Sanders-P ...

# %%
df = spark.sql('SELECT * FROM customer_churn_csv')

# %%
# %sql
WITH CTE As
(
SELECT company,count(company) as company_count
FROM customer_churn_csv
GROUP BY company
)
SELECT min(company_count) as min
      ,max(company_count) as max
      ,mean(company_count) as average
FROM CTE
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>min</th><th>max</th><th>average</th></tr></thead><tbody><tr><td>1</td><td>4</td><td>1.0309278350515463</td></tr></tbody></table></div>

# %%
df.columns
# Out:
# Out[4]: ['_c0',
#  'Names',
#  'Age',
#  'Total_Purchase',
#  'Account_Manager',
#  'Years',
#  'Num_Sites',
#  'Onboard_date',
#  'Location',
#  'Company',
#  'Churn']

# %%
data = df.select(['Age','Total_Purchase','Account_Manager','Years','Num_sites','Churn'])

# %%
from pyspark.sql.functions import count,when,isnan
data.select([count(when(isnan(c), c)).alias(c) for c in data.columns]).show()
# Out:
# +---+--------------+---------------+-----+---------+-----+
# |Age|Total_Purchase|Account_Manager|Years|Num_sites|Churn|
# +---+--------------+---------------+-----+---------+-----+
# |  0|             0|              0|    0|        0|    0|
# +---+--------------+---------------+-----+---------+-----+

# %%
from pyspark.ml.classification import LogisticRegression

# %%
from pyspark.ml.feature import VectorAssembler

# %%
assembler = VectorAssembler(inputCols = ['Age', 'Total_Purchase', 'Account_Manager', 'Years', 'Num_sites'],
                           outputCol = 'features')

# %%
output = assembler.transform(data)

# %%
final_data = output.select('features','churn')

# %%
train_churn,test_churn = final_data.randomSplit([0.7,0.3])

# %%
lr_churn = LogisticRegression(labelCol = 'churn')

# %%
fitted_churn_model = lr_churn.fit(train_churn)

# %%
training_summary = fitted_churn_model.summary

# %%
training_summary.predictions.describe().show()
# Out:
# +-------+------------------+-------------------+
# |summary|             churn|         prediction|
# +-------+------------------+-------------------+
# |  count|               633|                633|
# |   mean|0.1721958925750395|0.12796208530805686|
# | stddev|0.3778491924012704|0.33431176017391523|
# |    min|               0.0|                0.0|
# |    max|               1.0|                1.0|
# +-------+------------------+-------------------+

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator

# %%
test_pred_and_labels = fitted_churn_model.evaluate(test_churn)
train_pred_and_labels = fitted_churn_model.evaluate(train_churn)

# %%
pred_and_labels.predictions.show(5)
# Out:
# +--------------------+-----+--------------------+--------------------+----------+
# |            features|churn|       rawPrediction|         probability|prediction|
# +--------------------+-----+--------------------+--------------------+----------+
# |[26.0,8787.39,1.0...|    1|[0.86494964339695...|[0.70369373830952...|       0.0|
# |[28.0,8670.98,0.0...|    0|[7.68861107672528...|[0.99954219580438...|       0.0|
# |[28.0,11128.95,1....|    0|[4.35311608799206...|[0.98729679140599...|       0.0|
# |[28.0,11204.23,0....|    0|[2.08852815644445...|[0.88978316607676...|       0.0|
# |[29.0,9617.59,0.0...|    0|[4.34206906072332...|[0.98715749293747...|       0.0|
# +--------------------+-----+--------------------+--------------------+----------+
# only showing top 5 rows

# %%
churn_eval = BinaryClassificationEvaluator(labelCol = 'churn',
                                          rawPredictionCol='prediction')

# %%
train_auc = churn_eval.evaluate(train_pred_and_labels.predictions)
test_auc = churn_eval.evaluate(test_pred_and_labels.predictions)

# %%
train_auc,test_auc
# Out:
# Out[63]: (0.7662738987324044, 0.7727714224044896)

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
